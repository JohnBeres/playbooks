# %% [markdown]
# # T1052 Exfiltration Over Physical Medium
#
# -----------------------------------------------------------------------
#
# ## Technique Description
#
# Adversaries may attempt to exfiltrate data via a physical medium, such as a removable drive. In certain circumstances, such as an air-gapped network compromise, exfiltration could occur via a physical medium or device introduced by a user. Such media could be an external hard drive, USB drive, cellular phone, MP3 player, or other removable storage and processing device. The physical medium or device could be used as the final exfiltration point or to hop between otherwise disconnected systems.
#
# ## Technique Detection
#
# Monitor file access on removable media. Detect processes that execute when removable media are mounted.
#
# -----------------------------------------------------------------------
#
# ### Tactics:
#
#   *   Exfiltration
#
# ### Platforms:
#
#   * Linux
#
#   * macOS
#
#   * Windows
#
# ### System Requirements:
#
#   * Presence of physical medium or device
#
# ### Data Sources:
#
#   * **Process:** Process Creation
#
#   * **File:** File Access
#
#   * **Drive:** Drive Creation
#
#   * **Command:** Command Execution
#
# -----------------------------------------------------------------------
#
# ### Adversarial usage:
#
# | Adversary Group |  Adversarial Usage |
# |----|----|
# -----------------------------------------------------------------------
#
# ## Mitre References
#
#   * [Mitre-Attack](https://attack.mitre.org/techniques/T1052)
#
# > *Note: Do not edit this cell with information you want to keep. This cell will be wiped when the update script is ran. Store permanent information in one of the relevant cells below*
#
# *Last pulled from Mitre on: 23 June 2022*

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## Metadata
#
#   * **Last Updated  Date:** 8 July 2021
#
#   * **Author(s):** SSgt Johnathan Smith, SSgt John Beres
#
#   * **Validated:** NO
#
# -----------------------------------------------------------------------
#
# ## Overall Hypothesis
#
# - Adversaries will exfiltrate data via a physical medium.
#
# ## Adversary Examples
#
# | Adversary Specific Examples | Host Analytics | Network Analytics |
# |-----------------------------|----------------|-------------------|
# | APT 28 |  |  |
#
# ## Detection Blindspots
#
# - This technique may be primarily seen in air-gapped environments.
#
# ## Analytical References
#
#   * https://support.microsoft.com/en-us/help/967715/how-to-disable-the-autorun-functionality-in-windows
# * https://docs.microsoft.com/en-us/previous-versions/windows/it-pro/windows-server-2008-R2-and-2008/cc772540(v=ws.10)?redirectedfrom=MSDN
# * https://www.welivesecurity.com/2014/11/11/sednit-espionage-group-attacking-air-gapped-network

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## Host Analytics
#
# -----------------------------------------------------------------------
#
# ### Hunter Notes
#
# - Non-C: Drives in the filesystem are common in the form of Shared Drives. Look out for E:/ as that is the default letter for a Removable Media drive.
# - Legitimate uses of these tools may be performed by admins while they are working. Elimination of legitimate admin activity can be difficult; you can try to work with the MP to identify legitimate admin accounts and align those accounts with work schedules
# - At this point, remaining instances should be investigated more thoroughly. Consider the following:
#     - What is this drive? USB? DVD? Removable Disk? CD? Phone? etc.
#     - Is this a known drive on the network map?
#     - Why would an adversary want to collect the suggested information?
#     - And do those tasks fit with the expected work functions of that user?
#
# #### Analytic 1
#
#   * **Information:** 'Using Kibana, identify Windows Audits where filepath : [ starts with letter other than C:\ ]
# Note: This detection may lead to further discovery of data exfiltration via removable devices.'
#
#   * **Source:** 'Windows Audits'
#
#   * **Tool:** 'Kibana'
#
#   * **Notes:** 'Various notes to assist with hunting.'
#
#   * **Query:** ```Input your query here```

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## Network Analytics
#
# -----------------------------------------------------------------------
