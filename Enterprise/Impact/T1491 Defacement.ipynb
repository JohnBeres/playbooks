# %% [markdown]
# # T1491 Defacement
#
# -----------------------------------------------------------------------
#
# ## Technique Description
#
# Adversaries may modify visual content available internally or externally to an enterprise network, thus affecting the integrity of the original content. Reasons for [Defacement](https://attack.mitre.org/techniques/T1491) include delivering messaging, intimidation, or claiming (possibly false) credit for an intrusion. Disturbing or offensive images may be used as a part of [Defacement](https://attack.mitre.org/techniques/T1491) in order to cause user discomfort, or to pressure compliance with accompanying messages.
#
#
# ## Technique Detection
#
# Monitor internal and external websites for unplanned content changes. Monitor application logs for abnormal behavior that may indicate attempted or successful exploitation. Use deep packet inspection to look for artifacts of common exploit traffic, such as SQL injection. Web Application Firewalls may detect improper inputs attempting exploitation.
#
#
#
# -----------------------------------------------------------------------
#
# ### Tactics:
#
#   *   Impact
#
# ### Platforms:
#
#   * Windows
#
#   * IaaS
#
#   * Linux
#
#   * macOS
#
# ### Data Sources:
#
#   * **File:** File Creation
#
#   * **File:** File Modification
#
#   * **Application Log:** Application Log Content
#
#   * **Network Traffic:** Network Traffic Content
#
# -----------------------------------------------------------------------
#
# ### Adversarial usage:
#
# | Adversary Group |  Adversarial Usage |
# |----|----|
# -----------------------------------------------------------------------
#
# ## Mitre References
#
#   * [Mitre-Attack](https://attack.mitre.org/techniques/T1491)
#
# > *Note: Do not edit this cell with information you want to keep. This cell will be wiped when the update script is ran. Store permanent information in one of the relevant cells below*
#
# *Last pulled from Mitre on: 23 June 2022*

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## Metadata
#
#   * **Last Updated  Date:** 8 July 2021
#
#   * **Author(s):** SSgt Johnathan Smith, SSgt John Beres
#
#   * **Validated:** NO
#
# -----------------------------------------------------------------------
#
# ## Overall Hypothesis
#
# - Adversaries will modify visual content available internally or externally to an enterprise
#
# ## Adversary Examples
#
# | Adversary Specific Examples | Host Analytics | Network Analytics |
# |-----------------------------|----------------|-------------------|
# | Example APT/Threat actor | 1, 2 | 2, 3, 5|
#
# ## Detection Blindspots
#
# - Based on the data sources cited for this technique, a network analyst may provide better detection results.
#
# ## Analytical References
#
#   * https://www.techwalla.com/articles/how-to-change-desktop-wallpaper-using-regedit
# * https://www.windowscentral.com/how-restrict-users-changing-desktop-background-windows-10

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## Host Analytics
#
# -----------------------------------------------------------------------
#
# ### Hunter Notes
#
# - Monitor internal and external websites for unplanned content changes.
# - Monitor application logs for abnormal behavior that may indicate attempted or successful exploitation.
# - Use deep packet inspection to look for artifacts of common exploit traffic, such as SQL injection.
# - Web Application Firewalls may detect improper inputs attempting exploitation.
#
# #### Analytic 1
#
#   * **Information:** 'Monitor registry keys for desktop wallpaper or screenpaper modification'
#
#   * **Source:** 'Sysmon'
#
#   * **Tool:** 'Kibana'
#
#   * **Notes:** 'Various notes to assist with hunting.'
#
#   * **Query:** ```event.code : 12 or 13 or 14 AND TargetObject : HKEY_CURRENT_USER\SOFTWARE\Microsoft\Windows\CurrentVersion\Policies or KEY_CURRENT_USER\SOFTWARE\Microsoft\Windows\CurrentVersion\Screensavers or HKEY_CURRENT_USER\System\CurrentControlSet\Policies```

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## Network Analytics
#
# -----------------------------------------------------------------------
